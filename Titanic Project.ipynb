# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_Sex = LabelEncoder()
le_age= LabelEncoder()
le_cabin = LabelEncoder()
df["Sex"] = le_Sex.fit_transform(df["Sex"])
df["Age"] = le_age.fit_transform(df["Age"])
df["Cabin"]  =le_cabin.fit_transform(df["Cabin"])
newdf = pd.DataFrame()
newdf["PassengerId"] = df["PassengerId"]
newdf["Pclass"] = df["Pclass"]
newdf["Sex"] = df["Sex"]
newdf["Age"] = df["Age"]
newdf["SibSp"] = df["SibSp"]
newdf["Parch"] = df["Parch"]
newdf["Cabin"] = df["Cabin"]
newdff = pd.DataFrame()
newdff["Survived"] = df["Survived"]

# %%
clf.fit(newdf,newdff)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf.score(newdf,newdff)
# Out:
# 0.797979797979798

# %%
test_data= pd.read_csv("test.csv")

newdf2 = pd.DataFrame()
# newdf2["Sex"] = le_Sex.fit_transform(test_data["Sex"])
# newdf2["Age"] = le_age.fit_transform(test_data["Age"])
# newdf2["Cabin"]  =le_cabin.fit_transform(test_data["Cabin"])
newdf2["PassengerId"] = test_data["PassengerId"]
newdf2["Pclass"] = test_data["Pclass"]
newdf2["Sex"] = le_Sex.fit_transform(test_data["Sex"])
newdf2["Age"] = le_age.fit_transform(test_data["Age"])
# newdf2["Sex"] = test_data["Sex"]
# newdf2["Age"] = test_data["Age"]
newdf2["SibSp"] = test_data["SibSp"]
newdf2["Parch"] = test_data["Parch"]
# newdf2["Cabin"] = test_data["Cabin"]
newdf2["Cabin"]  =le_cabin.fit_transform(test_data["Cabin"])


ans = clf.predict(newdf2)

# %%
answer=pd.DataFrame()
answer['PassengerId'] = test_data["PassengerId"]
answer['Survived'] = ans
answer
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
answer.to_csv("/Users/hiesenberg/Data Scientist/predicted_answer1.csv",index = False)

# %%
answer = answer(index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3n/62nqk5qd02b687l25y2f4gdr0000gn/T/ipykernel_2265/1045087033.py in <module>
# ----> 1 answer = answer(index = False)
#
# TypeError: 'DataFrame' object is not callable
